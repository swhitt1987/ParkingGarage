# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
class ParkingGarage:
    def __init__(self, max_spaces=10, max_tickets=10):
        self.tickets = list(range(1, max_tickets + 1))
        self.parkingSpaces = list(range(1, max_spaces + 1))
        self.currentTicket = {}

    def takeTicket(self):
        if self.tickets:
            ticket = self.tickets.pop(0)
            space = self.parkingSpaces.pop(0)
            self.currentTicket[ticket] = {"space": space, "paid": False}
            print(f"Your ticket number is {ticket}. Please park in space {space}.")
        else:
            print("Sorry, the garage is full.")

    def payForParking(self):
        ticket = input("Please enter your ticket number: ")
        if int(ticket) in self.currentTicket:
            ticket = int(ticket)
            amount = input("Please enter the amount to pay: ")
            if amount:
                self.currentTicket[ticket]["paid"] = True
                print("Payment confirmed. You have 15 minutes to exit the garage.")
        else:
            print("Invalid number, please try again.")

    def leaveGarage(self):
        ticket = input("Please enter your ticket number: ")
        if int(ticket) in self.currentTicket:
            ticket = int(ticket)
            if self.currentTicket[ticket]["paid"]:
                space = self.currentTicket[ticket]["space"]
                self.parkingSpaces.append(space)
                self.tickets.append(ticket)
                del self.currentTicket[ticket]
                print("Thank you, have a nice day!")
            else:
                print("Please pay before leaving.")
        else:
            print("Invalid number, please try again.")

    def run(self):
        while True:
            action = input("Are you entering the garage, paying your ticket, or leaving the garage? (enter/pay/leave): ")
            if action == "enter":
                self.takeTicket()
            elif action == "pay":
                self.payForParking()
            elif action == "leave":
                self.leaveGarage()
            else:
                print("Please try again.")

garage = ParkingGarage()

garage.run()
# Out:
# Your ticket number is 1. Please park in space 1.
# Your ticket number is 2. Please park in space 2.
# Your ticket number is 3. Please park in space 3.
# Please pay before leaving.
# Payment confirmed. You have 15 minutes to exit the garage.
# Thank you, have a nice day!
# Your ticket number is 4. Please park in space 4.
# Your ticket number is 5. Please park in space 5.
# Your ticket number is 6. Please park in space 6.
# Payment confirmed. You have 15 minutes to exit the garage.
# Thank you, have a nice day!
# Invalid number, please try again.
# Your ticket number is 7. Please park in space 7.
# Your ticket number is 8. Please park in space 8.
# Your ticket number is 9. Please park in space 9.
# Please try again.
# Your ticket number is 10. Please park in space 10.
# Your ticket number is 2. Please park in space 2.
# Your ticket number is 3. Please park in space 3.
# Sorry, the garage is full.
# Payment confirmed. You have 15 minutes to exit the garage.
# Thank you, have a nice day!
# Your ticket number is 10. Please park in space 10.
# Sorry, the garage is full.
